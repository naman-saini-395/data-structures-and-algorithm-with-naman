# %% [markdown]
# string manipulation techniques

# %%
# 1 case coversion 

str1 = 'this is DATA SCIENCE'

# %%
# upper

str1.upper()
# Out:
# 'THIS IS DATA SCIENCE'

# %%
# lower

str1.lower()
# Out:
# 'this is data science'

# %%
# title

str2 = 'this is data science'

str2.title()
# Out:
# 'This Is Data Science'

# %%
# capitalize 

str2.capitalize()
# Out:
# 'This is data science'

# %%
# swapcase

str1
# Out:
# 'this is DATA SCIENCE'

# %%
str1.swapcase()
# Out:
# 'THIS IS data science'

# %% [markdown]
# # 2. Whitespace handling

# %%
str1 = '    this is DATA SCIENC   '
str1
# Out:
# '    this is DATA SCIENC   '

# %%
str1.strip()
# Out:
# 'this is DATA SCIENC'

# %%
# lstrip

str1.lstrip()
# Out:
# 'this is DATA SCIENC   '

# %%
# rstrip 
str1.rstrip()
# Out:
# '    this is DATA SCIENC'

# %% [markdown]
# # 3 searching & Fining

# %%
str1 = ' this is data science '
str1
# Out:
# ' this is data science '

# %%
# find 
str1.find('data')
# Out:
# 9

# %%
str1[9]
# Out:
# 'd'

# %%
str1.find('ml')
# Out:
# -1

# %%
# index 

str1.index('data')
# Out:
# 9

# %%
# startswith 
str1.startswith('data')
# Out:
# False

# %%
str1.startswith(' ')
# Out:
# True

# %%
# endswith 

str1.endswith(' ')
# Out:
# True

# %% [markdown]
# # 4 Validation Checks

# %%
str1 = 'this is data scinece and data engineering'
str1
# Out:
# 'this is data scinece and data engineering'

# %%
str2 = '1234'

# %%
# isdigit 

str2.isdigit()
# Out:
# True

# %%
#isalpha

'abcdABCD'.isalpha()
# Out:
# True

# %%
# isalnum


'adc123'.isalnum()
# Out:
# True

# %%
#islower

'abcd'.islower()
# Out:
# True

# %%
# isupper
'ABC'.isupper()
# Out:
# True

# %%
#isspace

'   '.isspace()
# Out:
# True

# %%
'  1 '.isspace()
# Out:
# False

# %% [markdown]
# # 5 Splitting & joining

# %%
str1
# Out:
# 'this is data scinece and data engineering'

# %%
# split

str1.split()
# Out:
# ['this', 'is', 'data', 'scinece', 'and', 'data', 'engineering']

# %%
# join

res = str1.split()
res
# Out:
# ['this', 'is', 'data', 'scinece', 'and', 'data', 'engineering']

# %%
' '.join(res).title()
# Out:
# 'This Is Data Scinece And Data Engineering'

# %% [markdown]
# # 6 Replacement

# %%
# repace 

str1
# Out:
# 'this is data scinece and data engineering'

# %%
str1.replace('scinece','hiii')
# Out:
# 'this is data hiii and data engineering'

# %% [markdown]
# # 7 counting & measuring

# %%
str1
# Out:
# 'this is data scinece and data engineering'

# %%
# len 

len(str1)
# Out:
# 41

# %%
#count

str1.count('data')
# Out:
# 2

# %%
str1.count('ml')
# Out:
# 0

# %%
str1.count('Data')
# Out:
# 0

# %% [markdown]
# # 8 string formatting

# %%
# f-strings 

first = 'naman'
last = 'saini'
age = '22'

res = f' MY name is {first} {last} and I am {age} year old.'
print(res)
# Out:
#  MY name is naman saini and I am 22 year old.

# %%
acc = 0.98
print(f'model accuracy: {acc}')
# Out:
# model accuracy: 0.98
