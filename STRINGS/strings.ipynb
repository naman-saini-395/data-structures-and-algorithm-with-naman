# %%
#1 stringd in python
# ways of creating a string

# %%
str1 = 'This is a strings in python'
print(str1)
print(type(str1))
# Out:
# This is a strings in python
# <class 'str'>

# %%
str2 = "This is also a stings in python "
print(str2)
print(type(str2))
# Out:
# This is also a stings in python
# <class 'str'>

# %%
print("Hii 'jhon")
# Out:
# Hii 'jhon

# %%
print('''This is a 
multi-linr string that spans 
multiple lines''')
# Out:
# This is a
# multi-linr string that spans
# multiple lines

# %%
# accessing characters of a stings0
str1
# Out:
# 'This is a strings in python'

# %%
str1[0]
# Out:
# 'T'

# %%
str1[-1]
# Out:
# 'n'

# %%
str1[4:10]
# Out:
# ' is a '

# %%
# 2 properties  of strings

#immutable

str1 = 'Hello'
print(id(str1))

str1 = str1 + 'world'
print(str1)
print(id(str1))
# Out:
# 2584329602512
# Helloworld
# 2584329538608

# %%
# iterble
str1
# Out:
# 'Helloworld'

# %%
for ch in str1:
    print(ch, end='')
# Out:
# Helloworld

# %%
#slicing

str1
# Out:
# 'Helloworld'

# %%
str1[2:5]
# Out:
# 'llo'

# %%
str1[1:9]
# Out:
# 'elloworl'

# %%
str1[1:9:2]
# Out:
# 'elwr'

# %%
#unicode
str1
# Out:
# 'Helloworld'

# %%
ord('a')# asikey values
# Out:
# 97

# %%
for ch in str1:
    print(ch,ord(ch))
# Out:
# H 72
# e 101
# l 108
# l 108
# o 111
# w 119
# o 111
# r 114
# l 108
# d 100

# %%
# concatenation 

s1 = 'Data'
s2 = 'Science'

s1 + ' ' +  s2
# Out:
# 'Data Science'

# %%
# Repetition 

s1
# Out:
# 'Data'

# %%
s1 * 3
# Out:
# 'DataDataData'

# %%
s2 = 'abc123gh'
print(type(s2[4]))
# Out:
# <class 'str'>

# %%
# common srting function

str1 = 'Data SCIEnce'

print(str1)
print(id(str1))
# Out:
# Data SCIEnce
# 2584335875440

# %%
#lower case

lower_str1 = str1.lower()

print(lower_str1)
print(id(lower_str1))
# Out:
# data science
# 2584336038448

# %%
str1
# Out:
# 'Data SCIEnce'

# %%
# upper

str1.upper()
# Out:
# 'DATA SCIENCE'

# %%
str2 = 'Tihs is 123 ABC '

print(str2.lower())
print(str2.upper())
# Out:
# tihs is 123 abc
# TIHS IS 123 ABC

# %%
# Strip

str3 = ' data science  '

# %%
str3.strip()
# Out:
# 'data science'

# %%
str4 = '###data science#######$$$$$@@@@'

str4.strip('#').strip('@').strip('$').strip('#')
# Out:
# 'data science'

# %%
str4
# Out:
# '###data science#######'

# %%
 # Replace
 
str1 = 'Data science'
str1
# Out:
# 'Data science'

# %%
str1.replace('science','Analysis')
# Out:
# 'Data Analysis'

# %%
str1.replace('a','z')
# Out:
# 'Dztz science'

# %%
str2 = 'Data science and Data Engineering '
str2
# Out:
# 'Data science and Data Engineering '

# %%
str2.replace('Data', 'data', 1)
# Out:
# 'data science and Data Engineering '

# %%
#split


str2
# Out:
# 'Data science and Data Engineering '

# %%
str2.split()
# Out:
# ['Data', 'science', 'and', 'Data', 'Engineering']

# %%
type(str2),type(str2.split())
# Out:
# (str, list)

# %%
str3 = 'Data-science-and-Data-Engineering'
str3
# Out:
# 'Data-science-and-Data-Engineering'

# %%
str3.split('-')
# Out:
# ['Data', 'science', 'and', 'Data', 'Engineering']

# %%
str3.split('Data')
# Out:
# ['', '-science-and-', '-Engineering']

# %%
name = 'Mr. James Anderson'

name.split(maxsplit=1)
# Out:
# ['Mr.', 'James Anderson']

# %%
#join

list1 = ['my ', 'name', 'is', 'jake']
list1
# Out:
# ['my ', 'name', 'is', 'jake']

# %%
' '.join(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ' '.join(list1)
#
# NameError: name 'list1' is not defined
