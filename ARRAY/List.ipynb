# %% [markdown]
# Lists

# %% [markdown]
# # creation
#
# number = [10,20,30]

# %%
number = [10,20,30,40,50]
fruits = ['apple', 'banana', 'cherry']
mixed_list = [7,3.14,'adc',True,None]

# %%
type(number)
# Out:
# list

# %%
#access 

number[2]
# Out:
# 30

# %%
fruits[1]
# Out:
# 'banana'

# %%
# traversal
for fruit in fruits:
    print(fruit, end=" ")
# Out:
# apple banana cherry

# %%
#insertion

#  append


number
# Out:
# [10, 20, 30, 40, 50]

# %%
number.append(60)

# %%
number
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
# insert 

number.insert(3,35)

# %%
number
# Out:
# [10, 20, 30, 35, 35, 40, 50, 60]

# %%
# merging

# %%
# entend

fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits = ['mango' , 'lemon']

# %%
fruits.extend(more_fruits)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon']

# %%
some_more_fruits = ('watermelon', 'kiwi')
fruits.extend(some_more_fruits)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon', 'watermelon', 'kiwi']

# %%
# concatenation
li1 = [1, 2, 3]
li2 = [4, 5 ]

# %%
li1 + li2
# Out:
# [1, 2, 3, 4, 5]

# %%
# deletion

# %%
li = [3, 4, 6, 4, 1, 6, 2]
print(li)

li.remove(6)
print(li)
# Out:
# [3, 4, 6, 4, 1, 6, 2]
# [3, 4, 4, 1, 6, 2]

# %%
 # pop 
 
number
# Out:
# [10, 20, 30, 35, 35, 40, 50, 60]

# %%
number.pop()
# Out:
# 60

# %%
number
# Out:
# [10, 20, 30, 35, 35, 40, 50]

# %%
number.pop(3)
number
# Out:
# [10, 20, 30, 35, 40, 50]

# %%
# del

del number[2]

# %%
number
# Out:
# [10, 20, 35, 40, 50]

# %%
li
# Out:
# [3, 4, 4, 1, 6, 2]

# %%
li.clear()

# %%
li
# Out:
# []

# %%
type(li)
# Out:
# list

# %%
# updation

mixed_list
# Out:
# [7, 3.14, 'adc', True, None]

# %%
mixed_list[1] = 6.626

print(mixed_list)
# Out:
# [7, 6.626, 'adc', True, None]

# %%
# count
li = [2, 3, 4, 2, 2, 5, 3]
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.count(2)
# Out:
# 3

# %%
# sorting
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.sort()

# %%
li
# Out:
# [2, 2, 2, 3, 3, 4, 5]

# %%
li1 = [2, 5, 3, 1, -4 ,5 ]
sorted(li1)
# Out:
# [-4, 1, 2, 3, 5, 5]

# %%
# reverse 

li1 = [3, 4, 1, 2, -5, 7, 4]
li1
# Out:
# [3, 4, 1, 2, -5, 7, 4]

# %%
li1.reverse()

# %%
li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
# copy 

li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li2 = li1.copy()
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li1.remove(4)
li1
# Out:
# [7, -5, 2, 1, 4, 3]

# %%
li1.pop()
# Out:
# 3

# %%
li1
# Out:
# [7, -5, 2, 1, 4]

# %%
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
#split 

number
# Out:
# [10, 20, 35, 40, 50]

# %%
number[:2]
# Out:
# [10, 20]

# %%
number[1:]
# Out:
# [20, 35, 40, 50]
