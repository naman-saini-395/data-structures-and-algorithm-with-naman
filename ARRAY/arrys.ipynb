# %% [markdown]
# ### 1. Array

# %% [markdown]
# #Arrays

# %%
import array

# %%
arr1 = array.array('i',[10, 20, 30, 40, 50,])
print(arr1)
# Out:
# array('i', [10, 20, 30, 40, 50])

# %%
arr2 =array.array('i',[60, 70, 80])
print(arr2)
# Out:
# array('i', [60, 70, 80])

# %%
#access 

arr1[2]
# Out:
# 30

# %%
arr1[3]
# Out:
# 40

# %%
#traversal
for element in arr1:
    print(element, end=" ")
# Out:
# 10 20 30 40 50

# %%
#insertion
arr1.insert(3,35)
print(arr1)
# Out:
# array('i', [10, 20, 30, 35, 40, 50])

# %%
# deletion

arr1.remove(30)
print(arr1)
# Out:
# array('i', [10, 20, 35, 40, 50])

# %%
# updation
arr1[2] = 30
print(arr1)
# Out:
# array('i', [10, 20, 30, 40, 50])

# %%
# sorting

arr3 = array.array('i', [4, 7, 3, 9 ,2, 6])
print(arr3)
# Out:
# array('i', [4, 7, 3, 9, 2, 6])

# %%
sorted_arr = array.array('i', sorted(arr3))
print(sorted_arr)
# Out:
# array('i', [2, 3, 4, 6, 7, 9])

# %%
# merging

arr1
# Out:
# array('i', [10, 20, 30, 40, 50])

# %%
arr2
# Out:
# array('i', [60, 70, 80])

# %%
arr4 = arr1 + arr2

# %%
#splitting 

ix = int(len(arr4)/2)
ix
# Out:
# 4

# %%
arr4[:ix]
# Out:
# array('i', [10, 20, 30, 40])

# %%
arr4[ix:]
# Out:
# array('i', [50, 60, 70, 80])

# %% [markdown]
# ### 2. numpy

# %%
import numpy as np

# %%
# creation 
np1 = np.array([10 , 20, 30, 40, 50])
np2 = np.array([50, 60, 70])
print(np1)
print(np2)
# Out:
# [10 20 30 40 50]
# [50 60 70]

# %%
# access
np1[0]
# Out:
# np.int64(10)

# %%
for ele in np1:
    print(ele, end=" ")
# Out:
# 10 20 30 40 50

# %%
# traverm
for ele in np1:
    print(ele, end=" ")
# Out:
# 10 20 30 40 50

# %%
# insertion 

np.insert(np1, 3 , 35)
# Out:
# array([10, 20, 30, 35, 40, 50])

# %%
# deletion
np.delete(np1,3)
# Out:
# array([10, 20, 30, 50])

# %%
# updation
np2[2]= 35
print(np1)
# Out:
# [10 20 30 40 50]

# %%
# sorting

np3 = np.array([5, 3, 7, 6, 2, 9])
np3
# Out:
# array([5, 3, 7, 6, 2, 9])

# %%
np.sort(np3)
# Out:
# array([2, 3, 5, 6, 7, 9])

# %%
# merging 
np1
# Out:
# array([10, 20, 30, 40, 50])

# %%
np2
# Out:
# array([50, 60, 35])

# %%
np3 =np.concatenate((np1,np2))
np3
# Out:
# array([10, 20, 30, 40, 50, 50, 60, 35])

# %%
# spliting 
split1, split2 = np.array_split(np3,2)

# %%
split2
# Out:
# array([50, 50, 60, 35])
